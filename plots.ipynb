# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.DataFrame([
    ['S4', 'Ours', 0.89],
    ['S4', 'Reported', 0.9113],
    ['LSSL-fixed', 'Ours', 0.862],
    ['LSSL-fixed', 'Reported', 0.8197],
    ['Transformer', 'Reported', 0.4442]
], columns=['Model', 'Source', 'Accuracy'])
data
# Out:
#          Model    Source  Accuracy
# 0           S4      Ours    0.8900
# 1           S4  Reported    0.9113
# 2   LSSL-fixed      Ours    0.8620
# 3   LSSL-fixed  Reported    0.8197
# 4  Transformer  Reported    0.4442

# %%
sns.barplot(data=data, hue='Source', x='Model', y='Accuracy')
plt.savefig('bars.png')
